# %% [markdown]
# # Homework Assignment 1 (Individual)
# ## Git practice, debugging practice, and new Python packages

# %% [markdown]
# ### <p style="text-align: right;"> &#9989; Laura Pascoe
# ### <p style="text-align: right;"> &#9989; pascoela

# %% [markdown]
# ### Goals for this homework assignment
# By the end of this assignment, you should be able will:
# * Demonstrate the purpose and utility of Git and demonstrate a workflow in practice.
# * Use Git to create a repository, track changes to the files within the repository, and push those changes to a remote repository.
# * Articulate the most common debugging strategies
# * Debug some basic Python code.
# * Read documentation and example code to use a new Python package
#
# Work through the following assignment, making sure to follow all of the directions and answer all of the questions.
#
# There are **100 points** possible on this assignment. Point values for each part are included in the section headers and question prompts.
#
# **This assignment is due roughly two weeks from now at 11:59 pm on Friday, February 3rd.** It should be uploaded into the "Homework Assignments" submission folder for Homework #1 on D2L.  Submission instructions can be found at the end of the notebook.

# %% [markdown]
# # Part 0: Office Hours and Academic Integrity (10 points)
#
# ## Academic integrity statement (2 Points)
#
# In the markdown cell below, paste your personal academic integrity statement. By including this statement, you are confirming that you are submitting this as your own work and not that of someone else.

# %% [markdown]
# <font size=6 color="#009600">&#9998;</font> I, Laura Pascoe, value the opportunity to further advance my education, the work and research others have done before me, and the academic community I am a part of. Because of these values and my respect for those who have helped me get to this point, I commit to conducting myself with integrity, including submitting work that is my own, citing sources when I receive help, and working to the best of my ability. I acknowledge my awareness of Michigan State University's policies and standards regarding academic integrity.

# %% [markdown]
# ## Going to Office Hours (8 Points)
#
# ### Why are we doing this?
# We want to make sure that everyone knows how to access the resources
# available to you. One of the best resources you have at your disposal is office hours.
#
# ### What will you do?
# (At minimum) Go to one office hour session ​(it doesn’t matter which one you go to). Come with one question that you would like to talk about. It can be big or small. Ask your question. All of the instructors for CMSE 202 (section leads, TAs, and LAs) will be adding to a running list of folks that we see during office hours; as long as your name appears on the list, you’ll get credit for this part of Homework 1.
#
# **NOTE:** The day when the homework is due (**Friday, February 3rd**) will be the busiest time for folks to go to office hours. You are **STRONGLY** encouraged to go to office hours before Friday to get credit for this part of this assignment. (You should still feel free to go to office hours on Friday for help, though!)
#
# You can find the office hours calendar on the [course website](https://cmse.msu.edu/cmse202).

# %% [markdown]
# **&#9989; **Question 0.1 (8 points)****
#
# Type below the question you asked.

# %% [markdown]
# <font size=6 color="#009600">&#9998;</font> I asked several questions including if we were supposed to respond to the "set x label vs label" in 2.2.2, and also why there are two different versions of the hw and if there was supposed to be one or two bugs in the squirrel simulation because mine said 1 but my friend's said 2

# %% [markdown]
# # Part 1: Designing a Workflow with Git (30 points total)
#
# You have spent some time in class learning about how/why we use git in CMSE 202 and beyond, and you will be expected to use it throughout the semester.
#
# ## 1.1 Propose a Software Development Workflow (10 points)
#
# You are working collaboratively with a team on a research project that includes developing code as well as writing a paper to communicate your results, and you need to ensure that all work is managed and tracked with git. Since you are learning about git in your class, your groupmates have asked you to propose a software development workflow for this project. Here, workflow is defined as the process by which the project is managed and developed.
#
# Your workflow must (at least) handle the following:
# 1. What role (or roles) will each person have?
# 2. How will changes be made/tracked?
# 3. What are your requirements for commit messages?
# 4. How do you expect people to work on their portions of the projects (using branches/merges)?
#
# In the cell below, write down the guidelines for your proposed workflow, making sure to account for all of the items mentioned above.

# %% [markdown]
# I would split the research project into the following sections:
# 1. Introduction (person 1, person 2)
# 2. Code/Analyses (person 3, person 4, person 5)
# 3. Methods (person 1, person 3)
# 4. Results (person 4, person 5)
# 5. Discussion (person 2, person 1)
# 6. References (all)
#
#
# I would start the project with a main document where all final sections will be added. I would assign two people to branch off to the introduction section (person 1 and person 2), where one person will write it initially, push it to the repo, then the second person will pull it, edit/peer review it, and push the edited version back. While those two work on the intro, another three people (person 3, person 4, person 5) would be assigned to work on the actual analyses/code. A separate code branch would be created off the main branch for initial code, then each person would be assigned a section of analyses to complete, and would have their own branch off that code branch to test things. Their working code would get pushed back into the code branch so everyone could double check/edit it in their own branch. When that is finalized, it will be pushed back to the main branch along with the intro work. Two people (person 1 and person 3) would look at the completed intro and analyses in order to write the methods section, which hinges on those two parts. A new branch off the main one would be created for the methods, where one of the coders would write the initial draft (person 3), then an intro writer (person 1) would edit to account for context/previous literature discussed in the introduction. This would be pushed into the main branch again. The coders would make a new branch to write up their results (person 4 and person 5. The results would get pushed back to the main branch for the discussion writers to review for additional info, intro writers (person 2, person 1) would make a discussion branch to work on. Then when the discussion was complete, it would be pushed as the last thing. Additionally, as shown in the drawing, references would be periodically added by everyone when final sections are pushed to the main branch. All commit messages would need to contain the paper section, their last name, and the current draft number (e.g., if I wrote the intro, my commit message would be “intro pascoe 1”), and any additions to the shared references section would need a commit message with their last name, and the shortened APA cites for the references they added (e.g., pascoe: klump et al., 2017; mikhail et al., 2022).

# %% [markdown]
# ![Image%20%282%29.jpeg](attachment:Image%20%282%29.jpeg)
#
# Attached image is a sketch of what it could look like, note that there could be many more branches as needed.

# %% [markdown]
# ## 1.2 Testing Your Workflow (10 points)
#
# In the cell(s) below, demonstrate that your workflow works by performing (or answering) the following tests:
#
# 1. A new person is joining your team, but they have never coded before and are concerned about making changes that might break your code. According to your workflow, what should their role be, and how should they make changes to the code?
# 2. Using vi (or your favorite text editor), create a file called paper_draft.txt. Following your workflow, make and commit changes to that file. Copy and paste any command line interface commands you use in the cell below.

# %% [markdown]
# The new person joining the team should create their own test branch off of the code/analyses branch in order to not break any working code. They can act as one of the coders, and according to my workflow, they would be assigned to a section of analyses to work on in their test branch, and once they have working code, merge it to the working branch

# %%
# cd into CMSE202-s23-turnin
vi paper_draft.txt
# text written, pretending this is the intro draft
git add paper_draft.txt
git commit -m "intro pascoe 1"
# Out:
#   File "<ipython-input-1-19a43dbbf7de>", line 2
#     vi paper_draft.txt
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 1.3 Reflecting (10 points)
#
# Answer the following questions in the cell below about your workflow:
#
# 1. What challenges/bugs did you run into when testing your workflow? How might you design for them in the future?
# 2. What worked well with your workflow?

# %% [markdown]
# 1. I could see there being issues with people trying to merge at the same time/needing to go back and work on past parts later on and that causing difficulties/errors. I think for accounting for them, it would just be important for the team to have communication outside of github (e.g., on slack, microsoft teams) to make sure everyone knows when someone intends to merge to the main branch, needs to go back and change a past part, etc. Also, I designed the coding aspect to be fairly individual where people are assigned a section to work on, then they add their working code to a main coding branch. While not written above, people are also welcome to share code within the test branches if they want to collaborate/need advice.
# 2. I feel like the timing of events in my workflow worked well just knowing how research projects are usually done (e.g., initial plan is made, intro is written to give context, analyses can be run at the same time with communication to the intro writers, methods is often drafted before actual analyses, but personally i find it easier to write it in detail after completing analyses, etc.), and I also feel like there were enough branches to let people work individually, but also enough "coming together" points to keep the project collaborative. I also feel like the rules for the commit messages would be helpful for the team, since they would know how many people had edited, what exact cites had been added, etc., without it being too wordy.

# %% [markdown]
# ## &#128721; STOP **COMMIT YOUR WORK TO GIT NOW**
#
# You should commit early and often, but at least do it after you complete each homework problem.
#
# Make sure to use meaningful commit messages that indicate the changes you have made!

# %% [markdown]
# # Part 2: Debugging Code (30 points total)
#
# Bugs are a part of life in writing code. They do not mean you are not making progress at coding. However, you can employ various debugging strategies to help you work through bugs efficiently and confidently.
#
# ## 2.1 Helping a CMSE 201 Student (10 points)
#
# In the cell below, explain debugging to a CMSE 201 student, and describe the process you would recommend they use to debug their code. You must include how you would solve the various types of bugs you can encounter while coding. Remember all of the resources you can use in CMSE 201/202 (particularly Google or other search engines!).

# %% [markdown]
# I would recommend first reading the error messages/looking at the line where the code breaks and/or checking if what the code spits out makes sense given what you want it to do. I would copy/paste error messages into google to figure out what they mean, then go on stack overflow or a similar resource for asking questions and see if someone else has had the same/similar issue, and see how they resolved it, or read articles/watch videos related to whatever the bug I'm experiencing is (e.g., if I'm having issues with getting a plot to look correct, read documentation about the plotting package I'm using, example code of others' plots, etc.) Additionally, looking at old code I've written can be really helpful, especially in the case of this class since 202 content builds off of 201 content (but that's not so helpful for a 201 student, more for me).

# %% [markdown]
# ## 2.2 Working Through Bugs (20 points total)
#
# ### 2.2.1 A Squirrelly Situation (10 points)
#
# Run the code in the cell below. There is (at least) 1 bug to find and fix! Complete the following questions:
#
# 1. Apply your debugging process to solve the bug(s) (showing the corrected code).
# 2. Did your process work? If so, continue to the next problem. If not, describe why and indicate any changes you would make to your process.

# %%
# function that returns a random number of squirrels spotted between 0 and the limit
def squirrel_spotting_simulation(limit=15):
    import numpy as np
    random_squirrels = np.random.randint(limit) #changed from 10 to the limit bc 10 made it so that the "increment = squirrel_spotting_simulation(15)" section wouldnt work correctly later, also not great to hard code things like these
    return random_squirrels

# initialize number of squirrels
squirrel_count = 0
# initialize number of time steps
t = 0

# loop until the observer reaches a maximum of 100 squirrels spotted
while squirrel_count <= 100:
    # use our function to generate a random number of squirrels spotted
    increment = squirrel_spotting_simulation(15)
    # increment the number of time steps by 1
    t+=1
    # add the number of random squirrels this time step to the total number
    squirrel_count+=increment

# print the total number of timesteps it took
print(t)
# Out:
# 11

# %% [markdown]
# 1. the bug was in the squirrel_spotting_simulation function, as the 10 in the np.random.randint(10) needed to be changed to np.random.randint(limit)
# 2. my debugging process written above did work since i found and resolved the bug after seeing that the output didn't seem quite correct, and looking back on past code i've written and seeing that hard coding like that is not ideal to do in general, and in this case was causing a bug

# %% [markdown]
# ## 2.2.2 Plotting and Scheming
#
# Run the code in the cell below, then answer the following questions:
#
#
# 1. Apply your debugging process to solve the bug (showing the corrected code).
# 2. Did your process work? If so, continue to the next problem. If not, describe why and indicate any changes you would make to your process.

# %%
# code to plot two randomly generated data sets (sin and cos) on one plot

import matplotlib.pyplot as plt
import numpy as np

# generate some x data: sixty data points from 0 to 4π
x_sin = np.linspace(0,4*np.pi,60)

# generate some y data: 1.5 * sin(1.2x + 0.5)
# we add the np.random.normal(0.25,.25,60) at the end to add some randomness to the data
y_sin = 1.5 * np.sin(1.2 * x_sin) + np.random.normal(.25,.25,60)

y_cos = 1.5 * np.cos(1.2 * x_sin) + np.random.normal(.25,.25,60)
# plot our data
plt.scatter(x_sin, y_sin, label = "sin data")
plt.scatter(x_sin, y_cos, label = "cos data") # moved to here
plt.xlabel('x')
plt.ylabel('y')
#plt.show() this was moved down
#plt.scatter(x_sin, y_cos, label = "cos data") this was moved up
plt.legend()
plt.show() # moved to here

# %% [markdown]
# 1. the bug was in the lower part of the code for the plot; things were out of order which was causing the data to be displayed in two plots instead of one, and one plot did not have x/y labels and one did not have a legend label.
# 2. my process also worked here since i found and resolved the bug, also by realizing that the plots definitely did not look right/match the comment that there should be two data sets on one plot, and then looking at past plots I've done with two data sets on one plot and looking at the order of the code.

# %% [markdown]
# ## &#128721; STOP **COMMIT YOUR WORK TO GIT NOW**
#
# You should commit early and often, but at least do it after you complete each homework problem.

# %% [markdown]
# # Part 3: New Packages (25 points total)
#
# In Part 1, you developed a workflow for the project your team is working on. One of your team members found this package that will help with some of the visualizations, however you discover that you don't currently have this package installed.
#
# A quick Google search tells you that the plotly Python library is an interactive, open-source plotting library that supports over 40 unique chart types covering a wide range of statistical, financial, geographic, scientific, and 3-dimensional use-cases. Sounds great, let's figure this out!
#
# ## 3.1 Install Package using CLI
# You remember from class that you can install packages using the command line. Using your terminal, install the plotly package, then answer the following questions.
#
# ### 3.1.1 (5 points):
#
# In the cell below, write down the command you used to install the package.

# %% [markdown]
# <font size=6 color="#009600">&#9998;</font> *Put your answer here.*

# %% [markdown]
# # IMPORTANT NOTE
#
# Particularly if you are using JupyterHub, you may get a message similar to this one in your terminal:
#
# ![package_exists.jpg](https://raw.githubusercontent.com/msu-cmse-courses/cmse202-S23-data/main//HW/HW1/package_exists.jpg)
#
# This means that the package has already been installed. If that is the case, you still need to provide the command you *would* use to install the package above, and then proceed to the rest of this problem.

# %% [markdown]
# ### 3.2 Reading Package Documentation
#
# Now that you've installed Plotly, its time to explore the package! What can this package do? The best place to find this information is in the [documentation](https://plotly.com/).
#
# ### 3.2.1 (10 points):
#
# Answer the following questions:
# 1. What kind of package is Plotly? (e.g. Mathematical, Graphing, Statistical, etc.)?
# 2. How many different tabs exist in the Plotly Open Source Graphing Libraries?
# 3. When would you use Plotly?
# 4. Are there any packages you know that are similar to plotly?
# 5. What are some different charts/plots you can create with Plotly?

# %% [markdown]
# <font size=6 color="#009600">&#9998;</font> *Put your answer here.*

# %% [markdown]
# ### 3.3 Using The New Package
# Finally, it's time to use the newly installed package! Pick a dataset from the [data package](https://plotly.com/python-api-reference/generated/plotly.data.html) that is a part of Plotly.
#
#
# ### 3.3.1 (10 points):
#
# Create a graph using one of these datasets. You can use the documentation for inspiration, but try to change the variables around so you get to really experience the package! Make sure to include titles and axis labels!

# %% [markdown]
# ---
#
# # Part 4: Finishing (5 points)
#
#
# &#9989; Have you put **your name** and **GitHub username** at the top of your notebook?
#
# &#9989; Have you added the **TA** and **Instructor** to your GitHub repository?
#
#
# &#9989; Push your repository to GitHub.
#
#
# ```bash
#
# # Put the command you used to push to GitHub here
# ```
#
#
# **NOTE:** The grader is able to see your commit messages and whether you pushed the repo at this stage.

# %% [markdown]
# ---
# ## Assignment wrap-up

# %% [markdown]
# ### Congratulations, you're done!
#
# Submit this assignment by uploading it to the course Desire2Learn web page.  Go to the **"Homework Assignments"** folder, find the dropbox link for Homework #1, and upload it there.

# %% [markdown]
# &#169; Copyright 2023,  Department of Computational Mathematics, Science and Engineering at Michigan State University
